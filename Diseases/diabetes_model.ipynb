# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
diabetes_dataset=pd.read_csv('diabetes.csv')

# %%
diabetes_dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_dataset.shape
# Out:
# (768, 9)

# %%
diabetes_dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
diabetes_dataset['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
gk=diabetes_dataset.groupby('Outcome')

# %%
gk.first()
# Out:
#          Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Outcome
# 0                  1       85             66             29        0  26.6
# 1                  6      148             72             35        0  33.6
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                           0.351   31
# 1                           0.627   50

# %%
gk=diabetes_dataset.groupby('Outcome').mean()

# %%
X = diabetes_dataset.drop(columns = 'Outcome', axis=1)
Y = diabetes_dataset['Outcome']

# %%
X.head(7)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
# 5                     0.201   30
# 6                     0.248   26

# %%
Y.head(7)
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# 5    0
# 6    1
# Name: Outcome, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
#visualize the data
X_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# mean      3.838762  121.529316      69.501629      20.741042   83.151466
# std       3.376108   31.756953      19.562986      16.082060  118.564627
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.250000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   44.000000
# 75%       6.000000  141.000000      80.000000      32.750000  130.000000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  614.000000                614.000000  614.000000
# mean    32.174104                  0.470274   33.257329
# std      8.002726                  0.335720   11.749655
# min      0.000000                  0.078000   21.000000
# ...

# %%
import plotly.express as px

# Assuming 'Age' column exists in X_train
fig = px.scatter(X_train, x='Pregnancies', y='Glucose', color='Age')
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
#graphs
fig = px.scatter(X_train, x='Pregnancies', y='Glucose', color='Age', marginal_y='violin',
          marginal_x='box', trendline='ols', template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="754d184b-0a9e-4be8-b6fc-b7e7c49ee0cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("754d184b-0a9e-4be8-b6fc-b7e7c49ee0cf")) {                    Plotly.newPlot(                        "754d184b-0a9e-4be8-b6fc-b7e7c49ee0cf",                        [{"hovertemplate":"Pregnancies=%{x}\u003cbr\u003eGlucose=%{y}\u003cbr\u003eAge=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[24,37,59,29,25,31,27,38,68,22,40,26,40,22,25,22,24,26,42,23,26,28,21,63,21,29,61,35,27,32,32,23,53,21,56,46,24,25,57,21,25,29,24,26,24,38,22,30,49,69,26,23,22,28,40,28,22,22,27,23,37,29,22,29,27,41,25,25,28,22,31,40,22,27,41,34,30,42,31,21,23,31,27,81,28,42,30,41,25,62,21,21,37,24,46,24,21,21,31
# ...

# %%
import plotly.express as px

fig = px.histogram(X_train, x='Pregnancies', marginal='violin', hover_data=X_train.columns, template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="e135a9fe-f466-44a9-9ae0-d6f48cdf7c2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e135a9fe-f466-44a9-9ae0-d6f48cdf7c2a")) {                    Plotly.newPlot(                        "e135a9fe-f466-44a9-9ae0-d6f48cdf7c2a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Pregnancies=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0,6,1,2,0,2,2,8,8,2,11,1,9,1,2,0,2,6,6,3,5,5,1,10,2,0,4,4,1,5,1,2,2,0,4,6,4,3,5,1,1,3,3,0,3,10,2,4,9,5,4,0,2,6,6,1,0,2,4,2,4,4,2,4,0,10,2,3,1,8,0,5,3,3,7,4,1,1,1,1,1,6,5,9,1,8,3,8,5,1,2,2,4,
# ...

# %%
#px graph for glucose
fig = px.histogram(X_train, x='Glucose', marginal='violin', hover_data=X_train.columns, template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="725bddfb-c8b5-4e7e-9e50-ac9aa603e068" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("725bddfb-c8b5-4e7e-9e50-ac9aa603e068")) {                    Plotly.newPlot(                        "725bddfb-c8b5-4e7e-9e50-ac9aa603e068",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Glucose=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[119,105,189,105,180,128,122,120,91,98,135,88,123,128,129,74,83,114,85,107,139,105,124,101,112,123,146,123,83,85,81,107,105,126,111,134,117,83,114,97,92,182,116,95,125,75,83,137,184,136,109,84,91
# ...

# %%
#px graph for blood pressure
fig = px.histogram(X_train, x='BloodPressure', marginal='violin', hover_data=X_train.columns, template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="ba6a7c39-2c69-4ba1-a000-38e763dd5338" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba6a7c39-2c69-4ba1-a000-38e763dd5338")) {                    Plotly.newPlot(                        "ba6a7c39-2c69-4ba1-a000-38e763dd5338",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"BloodPressure=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0,70,60,80,66,78,70,0,82,60,0,30,70,82,74,52,65,0,78,62,64,72,60,76,75,88,92,62,68,74,74,74,75,86,72,80,64,58,74,64,62,74,74,80,58,82,66,84,85,82,64,82,62,62,72,78,66,56,80,58,58,88,0,68,8
# ...

# %%
import plotly.express as px

fig = px.scatter_3d(X_train, x='Pregnancies', y='Glucose', z='BloodPressure', color='Age', size_max=18, opacity=0.7, template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="881686e8-d2e8-4b1d-a8fa-2574dbcf015d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("881686e8-d2e8-4b1d-a8fa-2574dbcf015d")) {                    Plotly.newPlot(                        "881686e8-d2e8-4b1d-a8fa-2574dbcf015d",                        [{"hovertemplate":"Pregnancies=%{x}\u003cbr\u003eGlucose=%{y}\u003cbr\u003eBloodPressure=%{z}\u003cbr\u003eAge=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[24,37,59,29,25,31,27,38,68,22,40,26,40,22,25,22,24,26,42,23,26,28,21,63,21,29,61,35,27,32,32,23,53,21,56,46,24,25,57,21,25,29,24,26,24,38,22,30,49,69,26,23,22,28,40,28,22,22,27,23,37,29,22,29,27,41,25,25,28,22,31,40,22,27,41,34,30,42,31,21,23,31,27,81,28,42,30,41,
# ...

# %%
#graph for reaming feature
fig = px.histogram(X_train, x='SkinThickness', marginal='violin', hover_data=X_train.columns, template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="07a63ea1-14f3-4162-9e59-3a04af4e503a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("07a63ea1-14f3-4162-9e59-3a04af4e503a")) {                    Plotly.newPlot(                        "07a63ea1-14f3-4162-9e59-3a04af4e503a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SkinThickness=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[0,32,23,45,39,37,27,0,0,17,0,42,44,17,26,10,28,0,0,13,35,29,32,48,32,37,0,0,0,22,41,30,0,27,47,37,27,31,0,19,25,0,15,45,0,0,23,0,15,0,44,31,0,31,27,39,40,28,0,17,28,47,0,0,17,0,22,48,49,0,
# ...

# %%
#3d graph for remaining features
fig = px.scatter_3d(X_train, x='Pregnancies', y='Glucose', z='SkinThickness', color='Age', size_max=18, opacity=0.7, template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="e60db2eb-b0c6-4f7a-b86f-5e3bbf06251e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e60db2eb-b0c6-4f7a-b86f-5e3bbf06251e")) {                    Plotly.newPlot(                        "e60db2eb-b0c6-4f7a-b86f-5e3bbf06251e",                        [{"hovertemplate":"Pregnancies=%{x}\u003cbr\u003eGlucose=%{y}\u003cbr\u003eSkinThickness=%{z}\u003cbr\u003eAge=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[24,37,59,29,25,31,27,38,68,22,40,26,40,22,25,22,24,26,42,23,26,28,21,63,21,29,61,35,27,32,32,23,53,21,56,46,24,25,57,21,25,29,24,26,24,38,22,30,49,69,26,23,22,28,40,28,22,22,27,23,37,29,22,29,27,41,25,25,28,22,31,40,22,27,41,34,30,42,31,21,23,31,27,81,28,42,30,41,
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (768, 8) (614, 8) (154, 8)

# %%
classifier = svm.SVC(kernel='linear')

# %%
classifier.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = classifier.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.7833876221498371

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = classifier.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [1]
# The person is diabetic
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but SVC was fitted with feature names

# %%
import pickle

# %%
filename = 'diabetes_model.sav'
pickle.dump(classifier, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('diabetes_model.sav', 'rb'))

# %%
input_data = (5,166,72,19,175,25.8,0.587,51)

# changing the input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = loaded_model.predict(input_data_reshaped)
print(prediction)

if (prediction[0] == 0):
  print('The person is not diabetic')
else:
  print('The person is diabetic')
# Out:
# [1]
# The person is diabetic
# c:\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning:
#
# X does not have valid feature names, but SVC was fitted with feature names

# %%
for column in X.columns:
  print(column)
# Out:
# Pregnancies
# Glucose
# BloodPressure
# SkinThickness
# Insulin
# BMI
# DiabetesPedigreeFunction
# Age
